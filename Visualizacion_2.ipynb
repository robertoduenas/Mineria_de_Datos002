# %% [markdown]
# ### Equipo: 2 Grupo: 002
#
# Integrantes:
#
# 1732753 Altamirano Romo Lizbeth Guadalupe
#
# 1725005 García Tamez Juan Manuel
#
# 1813599 González Baltazar Joel Gerardo
#
# 1797033 Herrera Dueñas Roberto Eduardo

# %% [markdown]
# # Pokemon

# %% [markdown]
# a) Pokemon Stats
#
# b) www.kaggle.com/abcsds/pokemon

# %% [markdown]
# #### Información estadística básica

# %%
import pandas as pd
d = pd.read_csv('Pokemon.csv')
d.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
d.drop(columns='Legendary',inplace=True)
d.drop(columns='Generation',inplace=True)
d.drop(columns='#',inplace=True)
d.drop(columns='Name',inplace=True)
d.drop(columns='Type 1',inplace=True)
d.drop(columns='Type 2',inplace=True)

d.head()
# Out:
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    318  45      49       49       65       65     45
# 1    405  60      62       63       80       80     60
# 2    525  80      82       83      100      100     80
# 3    625  80     100      123      122      120     80
# 4    309  39      52       43       60       50     65

# %%
d.tail()
# Out:
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 795    600  50     100      150      100      150     50
# 796    700  50     160      110      160      110    110
# 797    600  80     110       60      150      130     70
# 798    680  80     160       60      170      130     80
# 799    600  80     110      120      130       90     70

# %% [markdown]
# Eliminamos las columnas que no contengan numeros

# %%
d['Total'].sum()
# Out:
# 348082

# %%
d['Total'].cumsum()
# Out:
# 0         318
# 1         723
# 2        1248
# 3        1873
# 4        2182
#         ...
# 795    345502
# 796    346202
# 797    346802
# 798    347482
# 799    348082
# Name: Total, Length: 800, dtype: int64

# %%
d['Total'].median()
# Out:
# 450.0

# %%
d['Total'].var()
# Out:
# 14391.130907384233

# %%
d['Total'].skew()
# Out:
# 0.1525299233953993

# %%
d['Total'].kurt()
# Out:
# -0.5074607103228463

# %%
d['Total'].describe()
# Out:
# count    800.00000
# mean     435.10250
# std      119.96304
# min      180.00000
# 25%      330.00000
# 50%      450.00000
# 75%      515.00000
# max      780.00000
# Name: Total, dtype: float64

# %%
d['HP'].sum()
# Out:
# 55407

# %%
d['HP'].cumsum()
# Out:
# 0         45
# 1        105
# 2        185
# 3        265
# 4        304
#        ...
# 795    55117
# 796    55167
# 797    55247
# 798    55327
# 799    55407
# Name: HP, Length: 800, dtype: int64

# %%
d['HP'].median()
# Out:
# 65.0

# %%
d['HP'].var()
# Out:
# 652.0193225907373

# %%
d['HP'].skew()
# Out:
# 1.5682243758418617

# %%
d['HP'].kurt()
# Out:
# 7.232078374375156

# %%
d['HP'].describe()
# Out:
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: HP, dtype: float64

# %%
d['Attack'].sum()
# Out:
# 63201

# %%
d['Attack'].cumsum()
# Out:
# 0         49
# 1        111
# 2        193
# 3        293
# 4        345
#        ...
# 795    62661
# 796    62821
# 797    62931
# 798    63091
# 799    63201
# Name: Attack, Length: 800, dtype: int64

# %%
d['Attack'].median()
# Out:
# 75.0

# %%
d['Attack'].var()
# Out:
# 1053.4805991864816

# %%
d['Attack'].skew()
# Out:
# 0.5516137480269772

# %%
d['Attack'].kurt()
# Out:
# 0.1697173149230906

# %%
d['Attack'].describe()
# Out:
# count    800.000000
# mean      79.001250
# std       32.457366
# min        5.000000
# 25%       55.000000
# 50%       75.000000
# 75%      100.000000
# max      190.000000
# Name: Attack, dtype: float64

# %%
d['Defense'].sum()
# Out:
# 59074

# %%
d['Defense'].cumsum()
# Out:
# 0         49
# 1        112
# 2        195
# 3        318
# 4        361
#        ...
# 795    58724
# 796    58834
# 797    58894
# 798    58954
# 799    59074
# Name: Defense, Length: 800, dtype: int64

# %%
d['Defense'].median()
# Out:
# 70.0

# %%
d['Defense'].var()
# Out:
# 972.410707133917

# %%
d['Defense'].skew()
# Out:
# 1.1559123029560856

# %%
d['Defense'].kurt()
# Out:
# 2.726260359939344

# %%
d['Defense'].describe()
# Out:
# count    800.000000
# mean      73.842500
# std       31.183501
# min        5.000000
# 25%       50.000000
# 50%       70.000000
# 75%       90.000000
# max      230.000000
# Name: Defense, dtype: float64

# %%
d['Sp. Atk'].sum()
# Out:
# 58256

# %%
d['Sp. Atk'].cumsum()
# Out:
# 0         65
# 1        145
# 2        245
# 3        367
# 4        427
#        ...
# 795    57646
# 796    57806
# 797    57956
# 798    58126
# 799    58256
# Name: Sp. Atk, Length: 800, dtype: int64

# %%
d['Sp. Atk'].median()
# Out:
# 65.0

# %%
d['Sp. Atk'].var()
# Out:
# 1070.748535669585

# %%
d['Sp. Atk'].skew()
# Out:
# 0.7446624978300574

# %%
d['Sp. Atk'].kurt()
# Out:
# 0.29789366073147416

# %%
d['Sp. Atk'].describe()
# Out:
# count    800.000000
# mean      72.820000
# std       32.722294
# min       10.000000
# 25%       49.750000
# 50%       65.000000
# 75%       95.000000
# max      194.000000
# Name: Sp. Atk, dtype: float64

# %%
d['Sp. Def'].sum()
# Out:
# 57522

# %%
d['Sp. Def'].cumsum()
# Out:
# 0         65
# 1        145
# 2        245
# 3        365
# 4        415
#        ...
# 795    57062
# 796    57172
# 797    57302
# 798    57432
# 799    57522
# Name: Sp. Def, Length: 800, dtype: int64

# %%
d['Sp. Def'].var()
# Out:
# 774.4485544430531

# %%
d['Sp. Def'].median()
# Out:
# 70.0

# %%
d['Sp. Def'].skew()
# Out:
# 0.8540186115468782

# %%
d['Sp. Def'].kurt()
# Out:
# 1.628394056784738

# %%
d['Sp. Def'].describe()
# Out:
# count    800.000000
# mean      71.902500
# std       27.828916
# min       20.000000
# 25%       50.000000
# 50%       70.000000
# 75%       90.000000
# max      230.000000
# Name: Sp. Def, dtype: float64

# %%
d['Speed'].sum()
# Out:
# 54622

# %%
d['Sp. Def'].cumsum()
# Out:
# 0         65
# 1        145
# 2        245
# 3        365
# 4        415
#        ...
# 795    57062
# 796    57172
# 797    57302
# 798    57432
# 799    57522
# Name: Sp. Def, Length: 800, dtype: int64

# %%
d['Sp. Def'].median()
# Out:
# 70.0

# %%
d['Sp. Def'].var()
# Out:
# 774.4485544430531

# %%
d['Sp. Def'].skew()
# Out:
# 0.8540186115468782

# %%
d['Sp. Def'].kurt()
# Out:
# 1.628394056784738

# %%
d['Sp. Def'].describe()
# Out:
# count    800.000000
# mean      71.902500
# std       27.828916
# min       20.000000
# 25%       50.000000
# 50%       70.000000
# 75%       90.000000
# max      230.000000
# Name: Sp. Def, dtype: float64

# %%
d.corr()
# Out:
#             Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# Total    1.000000  0.618748  0.736211  0.612787  0.747250  0.717609  0.575943
# HP       0.618748  1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack   0.736211  0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense  0.612787  0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk  0.747250  0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def  0.717609  0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed    0.575943  0.175952  0.381240  0.015227  0.473018  0.259133  1.000000

# %%
d.cov()
# Out:
#                 Total           HP       Attack      Defense      Sp. Atk  \
# Total    14391.130907  1895.360178  2866.571837  2292.356589  2933.303830
# HP        1895.360178   652.019323   350.068512   190.801755   302.787559
# Attack    2866.571837   350.068512  1053.480599   444.010210   420.967685
# Defense   2292.356589   190.801755   444.010210   972.410707   228.108035
# Sp. Atk   2933.303830   302.787559   420.967685   228.108035  1070.748536
# Sp. Def   2395.697115   269.117875   238.449434   443.227428   460.887309
# Speed     2007.841358   130.565153   359.595397    13.798454   449.804706
#
#              Sp. Def        Speed
# Total    2395.697115  2007.841358
# HP        269.117875   130.565153
# Attack    238.449434   359.595397
# Defense   443.227428    13.798454
# Sp. Atk   460.887309   449.804706
# Sp. Def   774.448554   209.566514
# Speed     209.566514   844.511133

# %% [markdown]
# #### Graficar datos univariantes

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline
pok = pd.read_csv('Pokemon.csv')
pok.plot.bar
# Out:
# <bound method PlotAccessor.bar of <pandas.plotting._core.PlotAccessor object at 0x000002B6575080A0>>

# %%
pok['HP'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
pok['HP'].value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %%
pok['HP'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
pok['HP'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
pok['HP'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
pok[pok['HP'] < 50]['Attack'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pok['HP'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pok[pok['HP'] < 50].sample(100).plot.scatter(x='HP', y='Attack')
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
pok[pok['HP'] < 80].plot.scatter(x='HP', y='Attack')
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
pok[pok['HP'] < 80].plot.hexbin(x='HP', y='Attack', gridsize=15)
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
pok[pok['HP'] < 80].plot.hexbin(x='HP', y='Attack', gridsize=5)
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
pok.drop(columns='Legendary',inplace=True)
pok.drop(columns='Generation',inplace=True)
pok.drop(columns='#',inplace=True)
pok.drop(columns='Name',inplace=True)
pok.drop(columns='Type 1',inplace=True)
pok.drop(columns='Type 2',inplace=True)

# %%
pok.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
pok.plot.area()
# Out:
# <AxesSubplot:>

# %%
pok.plot.line()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.countplot(pok['HP'])
# Out:
# C:\Users\usuario5\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HP', ylabel='count'>

# %%
sns.kdeplot(pok.query('HP < 50').HP)
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
pok[pok['HP'] < 50]['HP'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df = pok[pok.HP.isin(pok.HP.value_counts().head(5).index)]

sns.boxplot(
    x='HP',
    y='Attack',
    data=df
)
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
sns.violinplot(
    x='HP',
    y='Attack',
    data=pok[pok.HP.isin(pok.HP.value_counts()[:5].index)]
)
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
sns.pairplot(pok[['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']])

# %%
pokem = pd.read_csv('Pokemon.csv')
import seaborn as sns
import matplotlib.pyplot as plt

sns.lmplot(x='HP', y='Attack', hue='Type 1', 
           data=pokem.loc[pokem['Type 1'].isin(['Water', 'Fire'])], 
           fit_reg=False)

# %%
m = plt.hist(pokem[pokem["Type 1"] == "Fire"].Attack,bins=30,fc = (1,0,0,0.5),label = "Fire")
b = plt.hist(pokem[pokem["Type 1"] == "Water"].Attack,bins=30,fc = (0,1,0,0.5),label = "Water")
plt.legend()
plt.xlabel("HP")
plt.ylabel("Attack")
plt.title("Histograma")
plt.show()

# %%
f,ax=plt.subplots(figsize = (18,18))
sns.heatmap(pokem.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# # Videojuegos

# %% [markdown]
# a) Videogames sales
#
# b) www.kaggle.com/migeruj/videogames-predictive-model

# %% [markdown]
# #### Información estadística básica

# %%
import pandas as pd
c = pd.read_csv('dato.csv')
c.head()
# Out:
#   Platform     Genre Publisher NA_Sales EU_Sales JP_Sales Other_Sales  \
# 0      Wii    Sports  Nintendo    41,36    28,96     3,77        8,45
# 1      Wii    Racing  Nintendo    15,68     12,8     3,79        3,29
# 2      Wii    Sports  Nintendo    15,61    10,95     3,28        2,95
# 3       DS  Platform  Nintendo    11,28     9,15      6,5        2,88
# 4      Wii      Misc  Nintendo    13,96     9,18     2,93        2,84
#
#   Global_Sales Rating Critic_Score_Class
# 0        82,54      E              Bueno
# 1        35,57      E          Excelente
# 2        32,78      E          Excelente
# 3        29,81      E          Excelente
# 4        28,92      E               Malo

# %%
c.drop(columns='Critic_Score_Class',inplace=True)
c.drop(columns='Rating',inplace=True)
c.drop(columns='Platform',inplace=True)
c.drop(columns='Genre',inplace=True)
c.drop(columns='Publisher',inplace=True)

       
c.head()
# Out:
#   NA_Sales EU_Sales JP_Sales Other_Sales Global_Sales
# 0    41,36    28,96     3,77        8,45        82,54
# 1    15,68     12,8     3,79        3,29        35,57
# 2    15,61    10,95     3,28        2,95        32,78
# 3    11,28     9,15      6,5        2,88        29,81
# 4    13,96     9,18     2,93        2,84        28,92

# %%
c.tail()
# Out:
#      NA_Sales EU_Sales JP_Sales Other_Sales Global_Sales
# 7107        0        0        0           0         0,01
# 7108        0        0        0           0         0,01
# 7109        0        0        0           0         0,01
# 7110        0        0        0           0         0,01
# 7111        0        0        0           0         0,01

# %% [markdown]
# Se eliminan las columnas que no contengan numeros.

# %%
import locale
locale.setlocale(locale.LC_ALL, 'nl_NL')
'nl_NL'
aux = 0
lista = []
for i in range(len(c['NA_Sales'])):
    a = locale.atof(c['NA_Sales'][i])
    lista.append(a)
aux = 0
lista1 = []
for i in range(len(c['EU_Sales'])):
    a = locale.atof(c['EU_Sales'][i])
    lista1.append(a)  
    
aux = 0
lista2 = []
for i in range(len(c['JP_Sales'])):
    a = locale.atof(c['JP_Sales'][i])
    lista2.append(a)
    
aux = 0
lista3 = []
for i in range(len(c['Other_Sales'])):
    a = locale.atof(c['Other_Sales'][i])
    lista3.append(a)

aux = 0
lista4 = []
for i in range(len(c['Global_Sales'])):
    a = locale.atof(c['Global_Sales'][i])
    lista4.append(a)
    
s = dataframe = pd.DataFrame(lista)
s1 = dataframe = pd.DataFrame(lista1)
s2 = dataframe = pd.DataFrame(lista2)
s3 = dataframe = pd.DataFrame(lista3)
s4 = dataframe = pd.DataFrame(lista4)

# %% [markdown]
# Cambiamos los datos a listas ya que no se podian trabajar con ellos de la forma original.
# Despues usamos el dataframe para que pudieramos utilizar la estadística básica

# %%
s.sum()
# Out:
# 0    2763.49
# dtype: float64

# %%
s.cumsum()
# Out:
#             0
# 0       41.36
# 1       57.04
# 2       72.65
# 3       83.93
# 4       97.89
# ...       ...
# 7107  2763.49
# 7108  2763.49
# 7109  2763.49
# 7110  2763.49
# 7111  2763.49
#
# [7112 rows x 1 columns]

# %%
s.median()
# Out:
# 0    0.15
# dtype: float64

# %%
s.var()
# Out:
# 0    0.910082
# dtype: float64

# %%
s.skew()
# Out:
# 0    16.256041
# dtype: float64

# %%
s.kurt()
# Out:
# 0    533.203966
# dtype: float64

# %%
s.describe()
# Out:
#                  0
# count  7112.000000
# mean      0.388567
# std       0.953982
# min       0.000000
# 25%       0.060000
# 50%       0.150000
# 75%       0.390000
# max      41.360000

# %%
s1.sum()
# Out:
# 0    1653.8
# dtype: float64

# %%
s1.cumsum()
# Out:
#             0
# 0       28.96
# 1       41.76
# 2       52.71
# 3       61.86
# 4       71.04
# ...       ...
# 7107  1653.80
# 7108  1653.80
# 7109  1653.80
# 7110  1653.80
# 7111  1653.80
#
# [7112 rows x 1 columns]

# %%
s1.median()
# Out:
# 0    0.06
# dtype: float64

# %%
s1.var()
# Out:
# 0    0.462438
# dtype: float64

# %%
s1.skew()
# Out:
# 0    16.125855
# dtype: float64

# %%
s1.kurt()
# Out:
# 0    508.634787
# dtype: float64

# %%
s1.describe()
# Out:
#                  0
# count  7112.000000
# mean      0.232537
# std       0.680028
# min       0.000000
# 25%       0.020000
# 50%       0.060000
# 75%       0.202500
# max      28.960000

# %%
s2.sum()
# Out:
# 0    445.58
# dtype: float64

# %%
s2.cumsum()
# Out:
#            0
# 0       3.77
# 1       7.56
# 2      10.84
# 3      17.34
# 4      20.27
# ...      ...
# 7107  445.58
# 7108  445.58
# 7109  445.58
# 7110  445.58
# 7111  445.58
#
# [7112 rows x 1 columns]

# %%
s2.cumsum()
# Out:
#            0
# 0       3.77
# 1       7.56
# 2      10.84
# 3      17.34
# 4      20.27
# ...      ...
# 7107  445.58
# 7108  445.58
# 7109  445.58
# 7110  445.58
# 7111  445.58
#
# [7112 rows x 1 columns]

# %%
s2.var()
# Out:
# 0    0.080358
# dtype: float64

# %%
s2.skew()
# Out:
# 0    10.666419
# dtype: float64

# %%
s2.kurt()
# Out:
# 0    152.099978
# dtype: float64

# %%
s2.describe()
# Out:
#                  0
# count  7112.000000
# mean      0.062652
# std       0.283475
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.010000
# max       6.500000

# %%
s3.sum()
# Out:
# 0    578.54
# dtype: float64

# %%
s3.cumsum()
# Out:
#            0
# 0       8.45
# 1      11.74
# 2      14.69
# 3      17.57
# 4      20.41
# ...      ...
# 7107  578.54
# 7108  578.54
# 7109  578.54
# 7110  578.54
# 7111  578.54
#
# [7112 rows x 1 columns]

# %%
s3.median()
# Out:
# 0    0.02
# dtype: float64

# %%
s3.var()
# Out:
# 0    0.070684
# dtype: float64

# %%
s3.skew()
# Out:
# 0    19.131798
# dtype: float64

# %%
s3.kurt()
# Out:
# 0    589.108685
# dtype: float64

# %%
s3.describe()
# Out:
#                  0
# count  7112.000000
# mean      0.081347
# std       0.265864
# min       0.000000
# 25%       0.010000
# 50%       0.020000
# 75%       0.070000
# max      10.570000

# %%
s4.sum()
# Out:
# 0    5442.86
# dtype: float64

# %%
s4.cumsum()
# Out:
#             0
# 0       82.54
# 1      118.11
# 2      150.89
# 3      180.70
# 4      209.62
# ...       ...
# 7107  5442.82
# 7108  5442.83
# 7109  5442.84
# 7110  5442.85
# 7111  5442.86
#
# [7112 rows x 1 columns]

# %%
s4.median()
# Out:
# 0    0.29
# dtype: float64

# %%
s4.var()
# Out:
# 0    3.750777
# dtype: float64

# %%
s4.skew()
# Out:
# 0    16.162536
# dtype: float64

# %%
s4.kurt()
# Out:
# 0    510.588485
# dtype: float64

# %%
s4.describe()
# Out:
#                  0
# count  7112.000000
# mean      0.765307
# std       1.936692
# min       0.010000
# 25%       0.110000
# 50%       0.290000
# 75%       0.742500
# max      82.540000

# %%
s
# Out:
#           0
# 0     41.36
# 1     15.68
# 2     15.61
# 3     11.28
# 4     13.96
# ...     ...
# 7107   0.00
# 7108   0.00
# 7109   0.00
# 7110   0.00
# 7111   0.00
#
# [7112 rows x 1 columns]

# %%
import numpy as np
df = pd.DataFrame(list(zip(lista,lista1,lista2,lista3,lista4)), columns = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales',])

# %%
df
# Out:
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0        41.36     28.96      3.77         8.45         82.54
# 1        15.68     12.80      3.79         3.29         35.57
# 2        15.61     10.95      3.28         2.95         32.78
# 3        11.28      9.15      6.50         2.88         29.81
# 4        13.96      9.18      2.93         2.84         28.92
# ...        ...       ...       ...          ...           ...
# 7107      0.00      0.00      0.00         0.00          0.01
# 7108      0.00      0.00      0.00         0.00          0.01
# 7109      0.00      0.00      0.00         0.00          0.01
# 7110      0.00      0.00      0.00         0.00          0.01
# 7111      0.00      0.00      0.00         0.00          0.01
#
# [7112 rows x 5 columns]

# %%
df.corr()
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# NA_Sales      1.000000  0.838223  0.465930     0.727575      0.954936
# EU_Sales      0.838223  1.000000  0.518536     0.718245      0.938461
# JP_Sales      0.465930  0.518536  1.000000     0.393503      0.611947
# Other_Sales   0.727575  0.718245  0.393503     1.000000      0.805426
# Global_Sales  0.954936  0.938461  0.611947     0.805426      1.000000

# %%
df.cov()
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# NA_Sales      0.910082  0.543784  0.126001     0.184535      1.764312
# EU_Sales      0.543784  0.462438  0.099959     0.129855      1.235958
# JP_Sales      0.126001  0.099959  0.080358     0.029657      0.335961
# Other_Sales   0.184535  0.129855  0.029657     0.070684      0.414712
# Global_Sales  1.764312  1.235958  0.335961     0.414712      3.750777

# %% [markdown]
# #### Graficar datos univariantes

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
df[df['NA_Sales'] < 10].value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='NA_Sales,EU_Sales,JP_Sales,Other_Sales,Global_Sales'>

# %%
df['NA_Sales'].value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df[df['NA_Sales'] < 10].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:xlabel='NA_Sales,EU_Sales,JP_Sales,Other_Sales,Global_Sales'>

# %%
df[df['NA_Sales'] < 10].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:xlabel='NA_Sales,EU_Sales,JP_Sales,Other_Sales,Global_Sales'>

# %%
df[df['NA_Sales'] < 10].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:xlabel='NA_Sales,EU_Sales,JP_Sales,Other_Sales,Global_Sales'>

# %%
df[df['NA_Sales'] < 1]['Global_Sales'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[df['NA_Sales'] < 10].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[df['NA_Sales'] < 50].sample(100).plot.scatter(x='NA_Sales', y='Global_Sales')
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='Global_Sales'>

# %%
df[df['NA_Sales'] < 10].plot.scatter(x='NA_Sales', y='Global_Sales')
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='Global_Sales'>

# %%
df[df['NA_Sales'] < 1].plot.hexbin(x='NA_Sales', y='Global_Sales', gridsize=15)
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='Global_Sales'>

# %%
df[df['NA_Sales'] < 1].plot.hexbin(x='NA_Sales', y='Global_Sales', gridsize=5)
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='Global_Sales'>

# %%
df[df['NA_Sales'] < 10].plot.area()
# Out:
# <AxesSubplot:>

# %%
df[df['NA_Sales'] < 10].plot.line()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.countplot(df['NA_Sales'] < 1)
# Out:
# C:\Users\usuario5\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NA_Sales', ylabel='count'>

# %%
sns.kdeplot(df.query('NA_Sales < 1').NA_Sales)
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='Density'>

# %%
df[df['NA_Sales'] < 1]['NA_Sales'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
sf = df[df.NA_Sales.isin(df[df['NA_Sales'] <5]['NA_Sales'].value_counts().head(20).index)]
sns.boxplot(
    x='NA_Sales',
    y='Global_Sales',
    data=sf
)
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='Global_Sales'>

# %%
sns.violinplot(
    x='NA_Sales',
    y='Global_Sales',
    data=df[df.NA_Sales.isin(df.NA_Sales.value_counts()[:].index)]
)
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='Global_Sales'>

# %%
sns.pairplot(df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
f,ax=plt.subplots(figsize = (18,18))
sns.heatmap(df.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()
